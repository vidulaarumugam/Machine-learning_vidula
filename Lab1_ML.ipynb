# %% [markdown]
# <a href="https://colab.research.google.com/github/vidulaarumugam/Machine-learning_vidula/blob/main/Lab1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
import pandas as pd #pandas are used to data manupulation
import numpy as np #used to solve multi dimensional and large matrix

# %%
from google.colab import files #importing files from google colb
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17e0f3b7-bb4b-4753-b40c-b1bfeae2f56a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e0f3b7-bb4b-4753-b40c-b1bfeae2f56a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Question1
excel = pd.ExcelFile('Lab Session1 Data.xlsx') #aceesing the excel
data = pd.read_excel(excel, 'Purchase data')

# %%
data
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#splitting data
A = data.iloc[:,1:4] #iloc is the command used to select rows and colums in python
C = data.iloc[:,4:6]
A #printing A
# Out:
#    Candies (#)  Mangoes (Kg)  Milk Packets (#)
# 0           20             6                 2
# 1           16             3                 6
# 2           27             6                 2
# 3           19             1                 2
# 4           24             4                 2
# 5           22             1                 5
# 6           15             4                 2
# 7           18             4                 2
# 8           21             1                 4
# 9           16             2                 4

# %%
C #printing c
# Out:
#    Payment (Rs)  Unnamed: 5
# 0           386         NaN
# 1           289         NaN
# 2           393         NaN
# 3           110         NaN
# 4           280         NaN
# 5           167         NaN
# 6           271         NaN
# 7           274         NaN
# 8           148         NaN
# 9           198         NaN

# %%
#dimensions
dimensionA = A.shape
dimensionC = C.shape
print(dimensionA)
print(dimensionC)
# Out:
# (10, 3)
# (10, 2)

# %%
A_vectors = A.shape[0]
C_vectors = C.shape[0]
print(A_vectors)
print(C_vectors)
# Out:
# 10
# 10

# %%
#rank of matrix
rank = np.linalg.matrix_rank(A) #method in python numpy tht is used to get rank
print(rank)
# Out:
# 3

# %%
pseudoInverse =  np.linalg.pinv(A) #linalg is built in function to get pseudo inverse
print(pseudoInverse)
# Out:
# [[-0.01008596 -0.03124505  0.01013951  0.0290728   0.0182907   0.01161794
#   -0.00771348  0.00095458  0.01743623 -0.00542016]
#  [ 0.09059668  0.07263726  0.03172933 -0.09071908 -0.01893196 -0.06926996
#    0.05675464  0.03152577 -0.07641966  0.00357352]
#  [ 0.00299878  0.15874243 -0.05795468 -0.06609024 -0.06295043  0.03348017
#    0.01541831 -0.01070461  0.00029003  0.05938755]]

# %% [markdown]
# #Q.A2

# %%
 x = np.matmul(pseudoInverse,C) #returns the matrix product of two arrays
x
# Out:
#    Payment (Rs)  Unnamed: 5
# 0           1.0         NaN
# 1          55.0         NaN
# 2          18.0         NaN

# %% [markdown]
# QA.3

# %%
info = np.where(data['Payment (Rs)']> 200, "Rich", "Poor")
print(info)
 # numpy.where(condition[, x, y]) is used to execute condition based statements
# Out:
# ['Rich' 'Rich' 'Rich' 'Poor' 'Rich' 'Poor' 'Rich' 'Rich' 'Poor' 'Poor']

# %% [markdown]
# Q.A4

# %%
import pandas as pd #pandas are used to data manupulation
import numpy as np #used to solve multi dimensional and large matrix

# %%
from google.colab import files #importing files from google colb
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fff8b890-b181-428f-ae64-b119081453b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fff8b890-b181-428f-ae64-b119081453b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
excel = pd.ExcelFile('Lab Session1 Data.xlsx') #import file from colab first
data2 = pd.read_excel(excel, 'IRCTC Stock Price')
print(data2)
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 0    Jun 29, 2021   Jun  Tue  2081.85  2092.00  2126.90  2065.05    1.67M
# 1    Jun 28, 2021   Jun  Mon  2077.75  2084.00  2112.45  2068.40  707.73K
# 2    Jun 25, 2021   Jun  Fri  2068.85  2084.35  2088.50  2053.10  475.82K
# 3    Jun 24, 2021   Jun  Thu  2072.95  2098.00  2098.00  2066.00  541.51K
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# ..            ...   ...  ...      ...      ...      ...      ...      ...
# 244  Jul 07, 2020   Jul  Tue  1397.40  1410.00  1411.00  1390.05  480.21K
# 245  Jul 06, 2020   Jul  Mon  1400.75  1405.50  1415.50  1394.00  614.93K
# 246  Jul 03, 2020   Jul  Fri  1405.10  1415.00  1425.00  1398.00  599.49K
# 247  Jul 02, 2020   Jul  Thu  1412.35  1440.00  1467.80  1395.30    2.16M
# 248  Jul 01, 2020   Jul  Wed  1363.05  1363.65  1377.00  1356.00  383.00K
#
#        Chg%
# 0    0.0020
# 1    0.0043
# 2   -0.0020
# 3   -0.0026
# ...

# %%
#a)mean and variance
mean  = data2['Price'].mean()
variance = data2['Price'].var()
print("Mean:",mean)
print("Variance:",variance)
# Out:
# Mean: 1560.6634538152612
# Variance: 58732.36535253918

# %%
#The .where() method in Pandas is used to perform conditional filtering on a DataFrame.
#Unlike the .query() method, which returns a filtered DataFrame with rows that satisfy
#the condition, the .where() method returns a new DataFrame with the same shape as the original but
#with the values replaced by NaN (Not a Number) where the condition is not met.

# %%
#b)query() method only works if the column name doesn’t have any empty spaces. The .query() method in Pandas allows you to filter rows from a DataFrame based on a boolean expression.

d = data2.query('Day == "Wed" & Price > 0')
mean_price = np.mean(d["Price"])
print("Sample Mean:",mean_price)

# Compare the mean with the population mean and note your observations
diff = mean_price-mean
print("Difference between sample mean and population mean: ",abs(diff)) #The abs () function returns the absolute value of the specified number.
#observation
if(mean_price>0):
  print("MeanPrice is greater ")
else:
  print("Population mean is greater")
# Out:
# Sample Mean: 1550.7060000000001
# Difference between sample mean and population mean:  9.957453815261033
# MeanPrice is greater

# %%
#c)Select the price data for the month of Apr and calculate the sample mean.
#same as b
d = data2.query('Month == "April" & Price > 0')
April_price = np.mean(d["Price"])
print("Sample Mean:",April_price)

#observation
diff = mean_price-mean
print("Difference between sample mean and population mean: ",abs(diff)) #The abs () function returns the absolute value of the specified number.
#observation
if(April_price>0):
  print("MeanPrice is greater ")
else:
  print("Population mean is greater")
# Out:
# Sample Mean: nan
# Difference between sample mean and population mean:  9.957453815261033
# Population mean is greater

# %%
#d)From the Chg% (available in column I) find the probability of making a loss over the stock.
count = data2['Chg%'].count()  #to count the total no of obseravtion the the datasheet
print(count)

data2['ChgProfit/Loss'] = data2['Chg%'].apply(lambda x: 'Profit' if x >= 0 else 'Loss') #A lambda function can take any number of arguments, but can only have one expression. Syntax lambda arguments : expression The expression is executed and the result is returned
count_of_profit = data2['ChgProfit/Loss'].value_counts()['Profit']
count_of_loss = data2['ChgProfit/Loss'].value_counts()['Loss']
print(count_of_loss)
#.apply() method in Pandas is used to apply a function along the axis of a DataFrame or Series. When using a lambda function with .apply(), you can create ad-hoc operations that are applied to each element or row/column of the
#prob og loss
prob_of_loss = count_of_loss/count
print ('The probability of making a loss over a stock is: ',prob_of_loss)
# Out:
# 249
# 124
# The probability of making a loss over a stock is:  0.4979919678714859

# %%
#e)Calculate the probability of making a profit on Wednesday.

wed = data2[data2["Day"]=="Wed"]  #creating a new data set called wed that contains all of the rows in the data2 data set where the Day column is equal to "Wed".

profit = list(filter(lambda x: x >0, wed['Chg%'])) #creating a new list called profit that contains all of the values in the Chg% column of the wed data set that are greater than 0

prob = len(profit)/data2["Chg%"].shape[0] #calculates the probability of making a profit on Wednesday by dividing the number of positive changes in the Chg% column by the total number of rows in the wed data set.

print("Probability of making a profit on Wednesday is: ", prob)
# Out:
# Probability of making a profit on Wednesday is:  0.08433734939759036

# %%
#f) Calculate the conditional probability of making profit, given that today is Wednesday.

wed = data2[data2["Day"]=="Wed"] #creates a new data set called

new_wed = wed.shape[0] #gets the number of rows in the wed data set

total = data2.shape[0] #gets the total number of rows in the data2 data set

prob_w = (new_wed/total) #calculation

print("Probability of the day being a Wednesday: ", prob_w) #
# Out:
# Probability of the day being a Wednesday:  0.20080321285140562

# %%
# Counting no.of days where we obtain profit and then finding P(Getting a profit)

count = data2['Chg%'].count()

data2['ChgProfit/Loss'] = data2['Chg%'].apply(lambda x: 'Profit' if x >= 0 else 'Loss') #This column contains the text "Profit" if the value in the Chg% column is greater than or equal to 0, and the text "Loss" if the value in the Chg% column is less than 0.

count_of_p = data2['ChgProfit/Loss'].value_counts()['Profit']

prob_p = count_of_p / 249

print("Probability of making a profit: ", prob_p)
# Out:
# Probability of making a profit:  0.5020080321285141

# %%
# Finding P(A intersection B)

intersect = prob_p*prob_w

finalprob = (intersect / prob_w) # Conditional probability

print("Conditional Probability of making a profit, given that today is Wednesday is: ", finalprob)
# Out:
# Conditional Probability of making a profit, given that today is Wednesday is:  0.5020080321285141

# %%
#g) Make a scatter plot of Chg% data against the day of the week.

print(data2.plot.scatter(x="Chg%",y="Day")) #The scatter plot will show the relationship between the Chg% data and the Day column.
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
#optional question

"""Create 2 separate square matrices from the purchase data matrix. Repeat experiments A2 & A3
with both these matrices. Do the X values obtained from the square matrices match to the one
obtained from the whole purchase data matrix?"""


# Find the dimensions of the purchase data matrix
m = data.shape[0]
n = data.shape[1]

print(m)
print(n)
# Out:
# 10
# 22

# %%
# Create two square matrices
square_matrix_1 = data[:10:10]
square_matrix_2 = data[:22:22]

print(square_matrix_1)
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17  Unnamed: 18  Candy  Mango  Milk
# 0          NaN          NaN    1.0   55.0  18.0
#
# [1 rows x 22 columns]

# %%
print(square_matrix_2)
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17  Unnamed: 18  Candy  Mango  Milk
# 0          NaN          NaN    1.0   55.0  18.0
#
# [1 rows x 22 columns]

# %%
# A3. Mark all customers (in “Purchase Data” table) with payments above Rs. 200 as RICH and others
# as POOR. Develop a classifier model to categorize customers into RICH or POOR class based on
# purchase behavior.

rich_customers = []
poor_customers = []

for i in range(m):
  if data[i, 4] > 200:
    rich_customers.append(i)
  else:
    poor_customers.append(i)

# Classify customers into RICH or POOR class based on purchase behavior

classifier = np.zeros((m, 2))

for i in range(m):
  if i in rich_customers:
    classifier[i, 0] = 1
  else:
    classifier[i, 1] = 1

# Compare the X values obtained from the square matrices to the X value obtained from the whole purchase data matrix

print("X value from square matrix 1:", x_value_1)
print("X value from square matrix 2:", x_value_2)

print("X value from whole purchase data matrix:", np.linalg.pinv(data)[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 4)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Define the two binary attribute vectors
vector_A = [1, 0, 1, 0, 1]
vector_B = [1, 1, 0, 0, 1]

# Calculate f11, f01, f10, and f00
f11 = sum(1 for a, b in zip(vector_A, vector_B) if a == 1 and b == 1)
f01 = sum(1 for a, b in zip(vector_A, vector_B) if a == 0 and b == 1)
f10 = sum(1 for a, b in zip(vector_A, vector_B) if a == 1 and b == 0)
f00 = sum(1 for a, b in zip(vector_A, vector_B) if a == 0 and b == 0)

# Calculate Jaccard Coefficient (JC)
JC = f11 / (f01 + f10 + f11)

# Calculate Simple Matching Coefficient (SMC)
SMC = (f11 + f00) / (f00 + f01 + f10 + f11)

# Print the results
print("Jaccard Coefficient (JC):", JC)
print("Simple Matching Coefficient (SMC):", SMC)
